# %%
l1=[1,2,3,4,5,6]
l1
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
l1[2]
# Out:
# 3

# %%
l1[-2]
# Out:
# 5

# %%
l1.pop()
# Out:
# 6

# %%
l1
# Out:
# [1, 2, 3, 4, 5]

# %%
l1.append(3)

# %%
l1
# Out:
# [1, 2, 3, 4, 5, 3]
